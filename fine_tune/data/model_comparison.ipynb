# %% [markdown]
# # These are the chat results of base and tuned models to be compared.

# %% [markdown]
# # Base model: gpt-4o
#
# ## 1.
#
# instructions: You are an AI assistant that helps people plan their travel.
#
# prompt: What can you do?
#
# response:
# Azure AI Foundry| gpt-4o-2024-11-20
# AI-generated content may be incorrect
#
# I can help you plan your travel in a variety of ways! Here’s what I can assist you with:
# Destination Recommendations
#
#     Suggest travel destinations based on your interests, budget, and preferred activities (e.g., beaches, hiking, history, food).
#     Recommend seasonal destinations for the best experiences.
#
# Itinerary Planning
#
#     Create detailed itineraries for your trip, including activities, attractions, and dining options.
#     Suggest day-by-day plans tailored to your interests and time frame.
#     Provide advice on the best times to visit specific places.
#
# Transportation Advice
#
#     Recommend the best ways to get to your destination (e.g., flights, trains, buses, or road trips).
#     Provide tips for navigating public transportation in cities or renting cars.
#     Help find reliable airlines or train routes for your journey.
#
# Accommodation Suggestions
#
#     Recommend hotels, hostels, vacation rentals, or other lodging options based on your budget and preferences.
#     Suggest neighborhoods to stay in for easy access to attractions or local culture.
#
# Budget Planning
#
#     Help you estimate costs for transportation, accommodations, food, and activities.
#     Suggest ways to save money, such as finding travel deals or cheaper alternatives.
#
# Travel Tips
#
#     Provide advice on packing essentials for your trip.
#     Share tips on visas, travel insurance, and other documentation.
#     Offer guidance on cultural norms, safety, and etiquette in your destination.
#
# Food and Dining Recommendations
#
#     Suggest local dishes and restaurants to try based on your preferences.
#     Find vegetarian, vegan, or dietary-specific food options.
#
# Activity Ideas
#
#     Recommend must-see attractions, hidden gems, and outdoor adventures.
#     Suggest kid-friendly, romantic, or group activities based on your travel companions.
#     Provide ideas for rainy day activities or off-the-beaten-path experiences.
#
# General Travel Advice
#
#     Help you navigate common travel challenges, like jet lag, currency exchange, or language barriers.
#     Recommend apps or tools for travel planning, navigation, and translation.
#
# Travel Documentation
#
#     Provide information on visa requirements, entry restrictions, and travel advisories.
#     Help you check for vaccination or health requirements for specific destinations.
#
# Custom Requests
#
#     Tailor recommendations to your unique needs, preferences, and priorities.
#     Answer specific questions about destinations or travel logistics.
#
# Let me know what you need help with, and I’ll do my best to make your travel planning smooth and enjoyable! 😊
#
#
# ## 2.
#
# instructions: You are an AI travel assistant that helps people plan their trips. Your objective is to offer support for travel-related inquiries, such as visa requirements, weather forecasts, local attractions, and cultural norms.
# You should not provide any hotel, flight, rental car or restaurant recommendations.
# Ask engaging questions to help someone plan their trip and think about what they want to do on their holiday.
#
#
# prompt: What can you do?
#
# response: Azure AI Foundry| gpt-4o-2024-11-20
# AI-generated content may be incorrect
#
# I’m here to make your travel planning easier and more enjoyable! Here’s what I can help you with:
#
#     Visa and Entry Requirements: I can help you understand if you need a visa or any other documents for your destination.
#
#     Weather Forecasts: I can tell you about the typical weather and seasons at your destination so you can pack appropriately.
#
#     Local Attractions: I can suggest must-see landmarks, natural wonders, and fun activities.
#
#     Cultural Norms and Etiquette: I can explain cultural differences and customs to help you blend in and show respect.
#
#     Packing Tips: I can help you figure out what to pack based on the weather, activities, and local norms.
#
#     Transportation Options: I can explain how to get around your destination, whether it’s by bus, train, taxi, or bike.
#
#     Safety Tips: I can provide information on staying safe and healthy while traveling.
#
#     Festivals and Events: I can let you know about any interesting festivals, holidays, or events happening during your visit.
#
#     Day Trip Ideas: I can suggest nearby destinations worth exploring if you have extra time.
#
#     Travel Inspiration: Not sure where to go? I can suggest destinations based on your interests—beaches, mountains, history, food, adventure, you name it!
#
# What kind of trip are you planning? A relaxing getaway, a cultural exploration, or maybe an outdoor adventure?

# %% [markdown]
# ## 3.
# Continue testing the model to review its behavior. For example, ask the following questions and note the model’s answers, paying particular attention to the tone and writing style that the model uses to respond:
#
# instructions: same as last
#
# prompt:
# Answer questions:
# Where in Rome should I stay?
# What are some local delicacies I should try?
# When is the best time of year to visit in terms of the weather?
# What's the best way to get around the city?
# I'm mostly there for the food. Where should I stay to be within walking distance of affordable restaurants?
#
# The response should have the following format:
# <question>
# <answer>
# ...
#
# Response Example:
# Q1: Where in Rome should I stay?
# A1: There are many beautiful places to stay in rome. Most famous hotels are ...
#
#
# ### response:
# Azure AI Foundry| gpt-4o-2024-11-20
# AI-generated content may be incorrect
#
# Q1: Where in Rome should I stay?
#
# A1: There are many beautiful places to stay in Rome. For a central and picturesque experience, consider staying in Trastevere, known for its cobblestone streets and lively atmosphere. Another option is Testaccio, a quieter neighborhood famous for its authentic Roman food scene. Both areas are well-connected and offer a mix of charm and convenience.
#
# Q2: What are some local delicacies I should try?
#
# A2: Rome offers an incredible array of local dishes. Be sure to try Cacio e Pepe (pasta with Pecorino Romano cheese and black pepper), Carbonara (pasta with guanciale, eggs, Pecorino cheese, and black pepper), Amatriciana (pasta with tomato sauce, guanciale, and Pecorino), Supplì (fried rice balls stuffed with mozzarella), Carciofi alla Romana (braised artichokes), and Maritozzo (a sweet cream-filled bun).
#
# Q3: When is the best time of year to visit in terms of the weather?
#
# A3: The best times to visit Rome are in spring (April to June) and fall (September to October). The weather is mild and pleasant, perfect for exploring the city on foot. Summer (July and August) can be very hot, while winter (December to February) is cooler and less crowded.
#
# Q4: What's the best way to get around the city?
#
# A4: Rome is very walkable, especially around the historic center. For longer distances, the Metro is quick and connects major attractions. Buses and trams are also available, but traffic can slow them down. Official white taxis are an option for convenience, but they can be pricey. Renting a bike or scooter is another way to explore, though the streets can be busy.
#
# Q5: I'm mostly there for the food. Where should I stay to be within walking distance of affordable restaurants?
#
# A5: For food enthusiasts, staying in Trastevere or Testaccio is ideal. Trastevere is bustling with trattorias and osterias offering authentic and affordable Roman dishes, while Testaccio is known as the culinary heart of the city, with traditional eateries and the famous Testaccio Market. Both neighborhoods are great for walking to a variety of dining options.
#
# Let me know if you'd like more tips or need help planning your itinerary!

# %% [markdown]
# # Comparison of responses base gpt-40 vs fine-tuned gpt-4o-2024-08-06-ft-travel models

# %%
from pathlib import Path
from dotenv import load_dotenv
import os

env_path = Path(r"C:\Users\valer\PROJECTS\AI_projects\learnings\azure_AI-103T00-A_traning\fine_tune\.env")

print(env_path.exists())

load_dotenv(env_path, override=True)

endpoint = os.getenv("PROJECT_ENDPOINT")
openai_base_url = os.getenv("OPENAI_BASE_URL")
openai_api_key = os.getenv("OPENAI_API_KEY")
model_deployment = os.getenv("MODEL_DEPLOYMENT_NAME")
tuned_model_deployment = os.getenv("TUNED_MODEL_DEPLOYMENT_NAME")
# Out:
# True

# %%
instructions =["You are an AI assistant that helps people plan their travel.",
    """You are an AI travel assistant that helps people plan their trips. Your objective is to offer support for travel-related inquiries, such as visa requirements, weather forecasts, local attractions, and cultural norms.
        You should not provide any hotel, flight, rental car or restaurant recommendations.
        Ask engaging questions to help someone plan their trip and think about what they want to do on their holiday."""
]

model_deployments = [model_deployment, tuned_model_deployment]

test_prompts = ["What can you do?","""
Answer questions: 
Where in Rome should I stay?
What are some local delicacies I should try?
When is the best time of year to visit in terms of the weather?
What's the best way to get around the city?
I'm mostly there for the food. Where should I stay to be within walking distance of affordable restaurants?

The response should have the following format:
<question>
<answer>
...

Response Example:
Q1: Where in Rome should I stay?
A1: There are many beautiful places to stay in rome. Most famous hotels are ..."""
]

# %%
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential
import pandas as pd

project = AIProjectClient(
    endpoint=os.environ["PROJECT_ENDPOINT"], #https://vst-5451-resource.services.ai.azure.com/api/projects/vst-5451
    credential=DefaultAzureCredential(),   #token
)

client = project.get_openai_client()

rows = []

for model_name in model_deployments:
    for instruction in instructions:
        for prompt in test_prompts:

            response = client.responses.create(
                model=model_name,
                instructions=instruction,
                input=prompt_text,
            )

            rows.append({
                "model_deployment": model_name,
                "instruction": instruction,
                "prompt": prompt,
                "response": response.output_text,
            })

            print("model:", model_name)
            print("instruction:", instruction)
            print("prompt:", prompt)
            print("-->response:", response.output_text)
            print()
            
df = pd.DataFrame(rows)
df
# Out:
# model: gpt-4o
# instruction: You are an AI assistant that helps people plan their travel.
# prompt: What can you do?
# -->response: I can help you plan your travels by providing information, tips, and personalized suggestions. Here’s a summary of what I can assist you with:
#
# ### 1. **Destination Guidance**
#    - Recommend destinations based on your preferences (e.g., activities, climate, location, budget).
#    - Compare places for vacations, honeymoons, family trips, etc.
#    - Share highlights and must-see attractions at your destination.
#
# ### 2. **Travel Itineraries**
#    - Create custom itineraries based on your interests, budget, and available time.
#    - Suggest things to do, places to eat, and transportation options in your chosen location.
#
# ### 3. **Budget Planning**
#    - Estimate costs for flights, accommodations, food, transportation, and activities.
#    - Suggest ways to save money without compromising your experience.
#
# ...

# %%
df.head(8)
# Out:
#               model_deployment  \
# 0                       gpt-4o
# 1                       gpt-4o
# 2                       gpt-4o
# 3                       gpt-4o
# 4  gpt-4o-2024-08-06-ft-travel
# 5  gpt-4o-2024-08-06-ft-travel
# 6  gpt-4o-2024-08-06-ft-travel
# 7  gpt-4o-2024-08-06-ft-travel
#
#                                          instruction  \
# 0  You are an AI assistant that helps people plan...
# 1  You are an AI assistant that helps people plan...
# 2  You are an AI travel assistant that helps peop...
# 3  You are an AI travel assistant that helps peop...
# 4  You are an AI assistant that helps people plan...
# 5  You are an AI assistant that helps people plan...
# 6  You are an AI travel assistant that helps peop...
# 7  You are an AI travel assistant that helps peop...
#
#                                               prompt  \
# 0                                   What can you do?
# 1  \nAnswer questions: \nWhere in Rome should I s...
# ...

# %%
df.to_csv("model_comparison_results.csv", index=False)

# %% [markdown]
# # Conclusion
#
# Test responses were generated for combinations of models[i], instructions[n], and prompts[m].
# See *model_comparison_results.csv* for details.
#
# - The tuned model returns more concise responses that are directly focused on the question.
# - Responses are shorter and more precise.
